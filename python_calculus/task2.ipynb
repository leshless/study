# %% [markdown]
# <a href="https://colab.research.google.com/github/leshless/study/blob/main/python_calculus/task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Практическое занятие 2
# ## Математический анализ
# ## Графики в Sympy
# https://docs.sympy.org/latest/tutorial/intro.html

# %%
# Вначале для простоты будем подключать модуль sympy целиком
from sympy import *
# А это уже магия!
# %matplotlib inline

# %% [markdown]
# ### Графики в Sympy

# %%
from sympy.plotting import *

# %% [markdown]
# #### Задание 5
# Построить на отрезке $[-2\pi,2\pi]$ график $tg(x)$ зеленым цветом, а график $ctg(x)$ красным, задать предел по вертикальной оси (-5, 5).

# %%
x = Symbol("x")

p = plot(xlim=[-2*pi, 2*pi], ylim=[-5, 5], show=False)
p.extend(plot(tan(x), line_color="g", show=False))
p.extend(plot(cot(x), line_color="r", show=False))

p.show()

# %% [markdown]
# #### Задание 6
# Построить графики логарифма по основанию 2, 10, $1/2$ и натурального логарифма в одной плоскости, каждый график отдельным цветом ('red', 'green', 'black', 'pink'). Отобразить название графика "Логарифмы по основанию 2, 10, $1/2$ и $e$", подписать горизонтальную ось $\phi$, вертикальную ось $\log_a\phi$.
# Включить легенду, в ней все функции подписать своими формулами, например, натуральный логарифм $\ln \phi$, десятичный $\lg \phi$.
#
# #### Указание.
# Можно составить подходящий словарь, list или tuple и использовать его в plot.
# Вначале можно построить только координатную плоскость с надписью графика и подписями осей, а также legend=True, а затем в цикле добавлять с помощью append графики логарифмов разных цветов.

# %%
x = Symbol("x")

p = plot(xlim=[-2*pi, 2*pi], ylim=[-5, 5], legend=True, xlabel="ϕ", ylabel="log a(ϕ)", title="Логарифмы по основанию 2, 10, 1/2 и e", show=False)
p.extend(plot(log(x, 2), line_color="red", label="log2(ϕ)", show=False))
p.extend(plot(log(x, 10), line_color="green", label="lg(ϕ)", show=False))
p.extend(plot(log(x, 1/2), line_color="black", label="log1/2(ϕ)", show=False))
p.extend(plot(log(x, E), line_color="pink", label="ln(ϕ)", show=False))

p.show()

# %% [markdown]
# #### Задание 7
# Изобразить на графике гиперболу, заданную своим каноническим уравнением
# $$
# \frac{x^2}{a^2}-\frac{y^2}{b^2}=1,
# $$
# при $a=3$, $b=5$. Масштаб по осям одинаковый, рекомендуемый интервал (-10, 10).

# %%
def f(x, y, a, b):
  return (x/a)**2 + (y/b)**2

x, y = symbols("x y")
p = plot_implicit(Eq(f(x, y, 3, 5), 1), (x, -10, 10), (y, -10, 10), show=False)

p.show()

# %% [markdown]
# ### Индивидуальное задание,
# Построить график параметрически заданной функции
# с соответствующими уравнениям подписями к осям.
# В легенде отразить уравнения функции в строчку
#
# ![image.png](data:image/png;base64,...)

# %%
rho = Symbol("rho")

p = plot(xlim=[-2*pi, 2*pi], ylim=[-5, 5], legend=True, xlabel="ρ", ylabel="μ(ρ)", show=False)
p.extend(plot(-6*cos(2*rho)**2, line_color="blue", label="μ₁(ρ) = -6cos²(2ρ)", show=False))
p.extend(plot(-5*cos(2*rho)**2,  line_color="red", label="μ₂(ρ) = -5cos²(2ρ)", show=False))

p.show()
